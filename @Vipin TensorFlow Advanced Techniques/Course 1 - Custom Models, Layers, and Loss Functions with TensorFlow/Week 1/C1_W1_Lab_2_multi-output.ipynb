# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 225.9127 - y1_output_loss: 108.0154 - y2_output_loss: 116.7053 - y1_output_root_mean_squared_error: 10.4280 - y2_output_root_mean_squared_error: 10.8245 - val_loss: 33.6031 - val_y1_output_loss: 15.0577 - val_y2_output_loss: 17.5285 - val_y1_output_root_mean_squared_error: 3.9383 - val_y2_output_root_mean_squared_error: 4.2535
# Epoch 2/500
# 614/614 [==============================] - 0s 150us/sample - loss: 33.5905 - y1_output_loss: 12.5615 - y2_output_loss: 20.9938 - y1_output_root_mean_squared_error: 3.5493 - y2_output_root_mean_squared_error: 4.5818 - val_loss: 40.4465 - val_y1_output_loss: 14.3935 - val_y2_output_loss: 25.9920 - val_y1_output_root_mean_squared_error: 3.8400 - val_y2_output_root_mean_squared_error: 5.0696
# Epoch 3/500
# 614/614 [==============================] - 0s 147us/sample - loss: 27.1877 - y1_output_loss: 10.0215 - y2_output_loss: 17.4871 - y1_output_root_mean_squared_error: 3.1434 - y2_output_root_mean_squared_error: 4.1602 - val_loss: 65.3462 - val_y1_output_loss: 19.3474 - val_y2_output_loss: 46.1972 - val_y1_output_root_mean_squared_error: 4.4429 - val_y2_output_root_mean_squared_error: 6.7533
# Epoch 4/500
# 614/614 [==============================] - 0s 149us/sample - loss: 33.1139 - y1_output_loss: 11.0416 - y2_output_loss: 22.0046 - y1_output_root_mean_squared_error: 3.3124 - y2_output_root_mean_squared_error: 4.7055 - val_loss: 24.8917 - val_y1_output_loss: 12.3478 - val_y2_output_loss: 11.8140 - val_y1_output_root_mean_squared_error: 3.5621 - val_y2_output_root_mean_squared_error: 3.4933
# Epoch 5/500
# 614/614 [==============================] - 0s 137us/sample - loss: 23.9080 - y1_output_loss: 9.2329 - y2_output_loss: 14.5674 - y1_output_root_mean_squared_error: 3.0493 - y2_output_root_mean_squared_error: 3.8223 - val_loss: 20.5981 - val_y1_output_loss: 9.6077 - val_y2_output_loss: 10.5647 - val_y1_output_root_mean_squared_error: 3.1567 - val_y2_output_root_mean_squared_error: 3.2609
# Epoch 6/500
# 614/614 [==============================] - 0s 140us/sample - loss: 26.3217 - y1_output_loss: 9.4449 - y2_output_loss: 17.1614 - y1_output_root_mean_squared_error: 3.0641 - y2_output_root_mean_squared_error: 4.1149 - val_loss: 24.2186 - val_y1_output_loss: 9.8825 - val_y2_output_loss: 13.5906 - val_y1_output_root_mean_squared_error: 3.1877 - val_y2_output_root_mean_squared_error: 3.7493
# Epoch 7/500
# 614/614 [==============================] - 0s 149us/sample - loss: 22.9463 - y1_output_loss: 8.8339 - y2_output_loss: 14.0218 - y1_output_root_mean_squared_error: 2.9820 - y2_output_root_mean_squared_error: 3.7489 - val_loss: 21.5427 - val_y1_output_loss: 9.9914 - val_y2_output_loss: 11.0639 - val_y1_output_root_mean_squared_error: 3.2174 - val_y2_output_root_mean_squared_error: 3.3453
# Epoch 8/500
# 614/614 [==============================] - 0s 143us/sample - loss: 22.3827 - y1_output_loss: 8.5544 - y2_output_loss: 13.7912 - y1_output_root_mean_squared_error: 2.9203 - y2_output_root_mean_squared_error: 3.7222 - val_loss: 18.8152 - val_y1_output_loss: 9.5808 - val_y2_output_loss: 8.8114 - val_y1_output_root_mean_squared_error: 3.1334 - val_y2_output_root_mean_squared_error: 2.9995
# Epoch 9/500
# 614/614 [==============================] - 0s 154us/sample - loss: 22.5999 - y1_output_loss: 8.5714 - y2_output_loss: 13.9756 - y1_output_root_mean_squared_error: 2.9336 - y2_output_root_mean_squared_error: 3.7409 - val_loss: 17.6674 - val_y1_output_loss: 9.0665 - val_y2_output_loss: 8.2306 - val_y1_output_root_mean_squared_error: 3.0529 - val_y2_output_root_mean_squared_error: 2.8892
# Epoch 10/500
# 614/614 [==============================] - 0s 145us/sample - loss: 26.1190 - y1_output_loss: 9.0748 - y2_output_loss: 16.8326 - y1_output_root_mean_squared_error: 3.0250 - y2_output_root_mean_squared_error: 4.1193 - val_loss: 24.0770 - val_y1_output_loss: 9.0624 - val_y2_output_loss: 14.2460 - val_y1_output_root_mean_squared_error: 3.0612 - val_y2_output_root_mean_squared_error: 3.8348
# Epoch 11/500
# 614/614 [==============================] - 0s 140us/sample - loss: 21.8209 - y1_output_loss: 8.3202 - y2_output_loss: 13.3452 - y1_output_root_mean_squared_error: 2.8966 - y2_output_root_mean_squared_error: 3.6648 - val_loss: 19.7428 - val_y1_output_loss: 8.8007 - val_y2_output_loss: 10.3342 - val_y1_output_root_mean_squared_error: 3.0138 - val_y2_output_root_mean_squared_error: 3.2649
# Epoch 12/500
# 614/614 [==============================] - 0s 139us/sample - loss: 22.3668 - y1_output_loss: 8.1619 - y2_output_loss: 14.0818 - y1_output_root_mean_squared_error: 2.8673 - y2_output_root_mean_squared_error: 3.7610 - val_loss: 17.4847 - val_y1_output_loss: 7.9205 - val_y2_output_loss: 9.4659 - val_y1_output_root_mean_squared_error: 2.8600 - val_y2_output_root_mean_squared_error: 3.0505
# Epoch 13/500
# 614/614 [==============================] - 0s 144us/sample - loss: 20.2525 - y1_output_loss: 7.5952 - y2_output_loss: 12.5571 - y1_output_root_mean_squared_error: 2.7649 - y2_output_root_mean_squared_error: 3.5507 - val_loss: 16.0372 - val_y1_output_loss: 7.2457 - val_y2_output_loss: 8.6878 - val_y1_output_root_mean_squared_error: 2.7357 - val_y2_output_root_mean_squared_error: 2.9246
# Epoch 14/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.4903 - y1_output_loss: 7.3017 - y2_output_loss: 13.0396 - y1_output_root_mean_squared_error: 2.7126 - y2_output_root_mean_squared_error: 3.6238 - val_loss: 14.1170 - val_y1_output_loss: 6.7074 - val_y2_output_loss: 7.1008 - val_y1_output_root_mean_squared_error: 2.6372 - val_y2_output_root_mean_squared_error: 2.6763
# Epoch 15/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.8812 - y1_output_loss: 6.8238 - y2_output_loss: 9.9521 - y1_output_root_mean_squared_error: 2.6175 - y2_output_root_mean_squared_error: 3.1670 - val_loss: 15.2862 - val_y1_output_loss: 7.3810 - val_y2_output_loss: 7.5402 - val_y1_output_root_mean_squared_error: 2.7637 - val_y2_output_root_mean_squared_error: 2.7655
# Epoch 16/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.8119 - y1_output_loss: 6.4674 - y2_output_loss: 9.3661 - y1_output_root_mean_squared_error: 2.5364 - y2_output_root_mean_squared_error: 3.0625 - val_loss: 16.6081 - val_y1_output_loss: 7.0526 - val_y2_output_loss: 9.6280 - val_y1_output_root_mean_squared_error: 2.6933 - val_y2_output_root_mean_squared_error: 3.0585
# Epoch 17/500
# 614/614 [==============================] - 0s 155us/sample - loss: 15.8643 - y1_output_loss: 6.2024 - y2_output_loss: 10.1063 - y1_output_root_mean_squared_error: 2.4608 - y2_output_root_mean_squared_error: 3.1319 - val_loss: 68.3615 - val_y1_output_loss: 20.2860 - val_y2_output_loss: 47.8683 - val_y1_output_root_mean_squared_error: 4.5608 - val_y2_output_root_mean_squared_error: 6.8964
# Epoch 18/500
# 614/614 [==============================] - 0s 143us/sample - loss: 17.0339 - y1_output_loss: 6.7244 - y2_output_loss: 10.1835 - y1_output_root_mean_squared_error: 2.6040 - y2_output_root_mean_squared_error: 3.2020 - val_loss: 14.2711 - val_y1_output_loss: 6.3125 - val_y2_output_loss: 8.0448 - val_y1_output_root_mean_squared_error: 2.5467 - val_y2_output_root_mean_squared_error: 2.7903
# Epoch 19/500
# 614/614 [==============================] - 0s 139us/sample - loss: 15.8436 - y1_output_loss: 5.7250 - y2_output_loss: 10.2224 - y1_output_root_mean_squared_error: 2.3911 - y2_output_root_mean_squared_error: 3.1822 - val_loss: 16.5226 - val_y1_output_loss: 6.5951 - val_y2_output_loss: 10.4764 - val_y1_output_root_mean_squared_error: 2.5856 - val_y2_output_root_mean_squared_error: 3.1364
# Epoch 20/500
# 614/614 [==============================] - 0s 142us/sample - loss: 14.2120 - y1_output_loss: 5.4345 - y2_output_loss: 8.7042 - y1_output_root_mean_squared_error: 2.3382 - y2_output_root_mean_squared_error: 2.9572 - val_loss: 12.4546 - val_y1_output_loss: 5.6701 - val_y2_output_loss: 7.0111 - val_y1_output_root_mean_squared_error: 2.3989 - val_y2_output_root_mean_squared_error: 2.5885
# Epoch 21/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.7908 - y1_output_loss: 5.6199 - y2_output_loss: 9.3691 - y1_output_root_mean_squared_error: 2.3373 - y2_output_root_mean_squared_error: 3.0541 - val_loss: 32.4214 - val_y1_output_loss: 11.7599 - val_y2_output_loss: 21.2867 - val_y1_output_root_mean_squared_error: 3.4423 - val_y2_output_root_mean_squared_error: 4.5356
# Epoch 22/500
# 614/614 [==============================] - 0s 140us/sample - loss: 12.1088 - y1_output_loss: 4.7007 - y2_output_loss: 7.3893 - y1_output_root_mean_squared_error: 2.1769 - y2_output_root_mean_squared_error: 2.7148 - val_loss: 26.4672 - val_y1_output_loss: 7.7427 - val_y2_output_loss: 17.8117 - val_y1_output_root_mean_squared_error: 2.8295 - val_y2_output_root_mean_squared_error: 4.2967
# Epoch 23/500
# 614/614 [==============================] - 0s 139us/sample - loss: 12.9252 - y1_output_loss: 4.9368 - y2_output_loss: 7.9243 - y1_output_root_mean_squared_error: 2.2235 - y2_output_root_mean_squared_error: 2.8251 - val_loss: 11.1922 - val_y1_output_loss: 4.8058 - val_y2_output_loss: 6.5848 - val_y1_output_root_mean_squared_error: 2.2073 - val_y2_output_root_mean_squared_error: 2.5140
# Epoch 24/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.9632 - y1_output_loss: 5.2983 - y2_output_loss: 9.6751 - y1_output_root_mean_squared_error: 2.2978 - y2_output_root_mean_squared_error: 3.1118 - val_loss: 18.6626 - val_y1_output_loss: 7.1389 - val_y2_output_loss: 12.1053 - val_y1_output_root_mean_squared_error: 2.6769 - val_y2_output_root_mean_squared_error: 3.3907
# Epoch 25/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.0189 - y1_output_loss: 4.5802 - y2_output_loss: 7.3281 - y1_output_root_mean_squared_error: 2.1505 - y2_output_root_mean_squared_error: 2.7193 - val_loss: 9.2566 - val_y1_output_loss: 4.2477 - val_y2_output_loss: 5.1904 - val_y1_output_root_mean_squared_error: 2.0763 - val_y2_output_root_mean_squared_error: 2.2239
# Epoch 26/500
# 614/614 [==============================] - 0s 142us/sample - loss: 12.1786 - y1_output_loss: 4.5336 - y2_output_loss: 7.8996 - y1_output_root_mean_squared_error: 2.1066 - y2_output_root_mean_squared_error: 2.7822 - val_loss: 20.1292 - val_y1_output_loss: 5.8567 - val_y2_output_loss: 15.2128 - val_y1_output_root_mean_squared_error: 2.4113 - val_y2_output_root_mean_squared_error: 3.7835
# Epoch 27/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.6343 - y1_output_loss: 4.4007 - y2_output_loss: 8.3532 - y1_output_root_mean_squared_error: 2.0850 - y2_output_root_mean_squared_error: 2.8788 - val_loss: 44.6681 - val_y1_output_loss: 11.6565 - val_y2_output_loss: 33.8758 - val_y1_output_root_mean_squared_error: 3.4215 - val_y2_output_root_mean_squared_error: 5.7412
# Epoch 28/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.0439 - y1_output_loss: 4.7213 - y2_output_loss: 9.2198 - y1_output_root_mean_squared_error: 2.1808 - y2_output_root_mean_squared_error: 3.0476 - val_loss: 10.2311 - val_y1_output_loss: 4.5703 - val_y2_output_loss: 5.6794 - val_y1_output_root_mean_squared_error: 2.1633 - val_y2_output_root_mean_squared_error: 2.3561
# Epoch 29/500
# 614/614 [==============================] - 0s 141us/sample - loss: 9.0354 - y1_output_loss: 3.3050 - y2_output_loss: 5.7375 - y1_output_root_mean_squared_error: 1.8192 - y2_output_root_mean_squared_error: 2.3929 - val_loss: 15.7141 - val_y1_output_loss: 5.7132 - val_y2_output_loss: 10.6300 - val_y1_output_root_mean_squared_error: 2.3913 - val_y2_output_root_mean_squared_error: 3.1616
# Epoch 30/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.1044 - y1_output_loss: 3.9069 - y2_output_loss: 7.2323 - y1_output_root_mean_squared_error: 1.9739 - y2_output_root_mean_squared_error: 2.6848 - val_loss: 11.4597 - val_y1_output_loss: 4.2807 - val_y2_output_loss: 7.5934 - val_y1_output_root_mean_squared_error: 2.0799 - val_y2_output_root_mean_squared_error: 2.6709
# Epoch 31/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.2980 - y1_output_loss: 3.1755 - y2_output_loss: 6.0482 - y1_output_root_mean_squared_error: 1.7894 - y2_output_root_mean_squared_error: 2.4690 - val_loss: 8.0046 - val_y1_output_loss: 3.0363 - val_y2_output_loss: 5.2445 - val_y1_output_root_mean_squared_error: 1.7535 - val_y2_output_root_mean_squared_error: 2.2203
# Epoch 32/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.6792 - y1_output_loss: 3.3572 - y2_output_loss: 6.4559 - y1_output_root_mean_squared_error: 1.8349 - y2_output_root_mean_squared_error: 2.5124 - val_loss: 24.1769 - val_y1_output_loss: 5.7316 - val_y2_output_loss: 18.9452 - val_y1_output_root_mean_squared_error: 2.4147 - val_y2_output_root_mean_squared_error: 4.2832
# Epoch 33/500
# 614/614 [==============================] - 0s 145us/sample - loss: 9.9849 - y1_output_loss: 3.4009 - y2_output_loss: 6.6101 - y1_output_root_mean_squared_error: 1.8469 - y2_output_root_mean_squared_error: 2.5640 - val_loss: 8.2628 - val_y1_output_loss: 3.2807 - val_y2_output_loss: 5.1895 - val_y1_output_root_mean_squared_error: 1.8307 - val_y2_output_root_mean_squared_error: 2.2161
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 10.3481 - y1_output_loss: 3.4299 - y2_output_loss: 6.9015 - y1_output_root_mean_squared_error: 1.8519 - y2_output_root_mean_squared_error: 2.6303 - val_loss: 9.4759 - val_y1_output_loss: 3.4314 - val_y2_output_loss: 5.9485 - val_y1_output_root_mean_squared_error: 1.8781 - val_y2_output_root_mean_squared_error: 2.4390
# Epoch 35/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.0000 - y1_output_loss: 2.8717 - y2_output_loss: 5.0631 - y1_output_root_mean_squared_error: 1.7019 - y2_output_root_mean_squared_error: 2.2591 - val_loss: 8.8317 - val_y1_output_loss: 3.3991 - val_y2_output_loss: 5.4529 - val_y1_output_root_mean_squared_error: 1.8735 - val_y2_output_root_mean_squared_error: 2.3069
# Epoch 36/500
# 614/614 [==============================] - 0s 149us/sample - loss: 9.2148 - y1_output_loss: 3.2235 - y2_output_loss: 5.9808 - y1_output_root_mean_squared_error: 1.7941 - y2_output_root_mean_squared_error: 2.4487 - val_loss: 14.4147 - val_y1_output_loss: 4.7671 - val_y2_output_loss: 9.9821 - val_y1_output_root_mean_squared_error: 2.2074 - val_y2_output_root_mean_squared_error: 3.0891
# Epoch 37/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.2161 - y1_output_loss: 2.7668 - y2_output_loss: 5.5427 - y1_output_root_mean_squared_error: 1.6623 - y2_output_root_mean_squared_error: 2.3351 - val_loss: 15.4216 - val_y1_output_loss: 3.1573 - val_y2_output_loss: 11.7361 - val_y1_output_root_mean_squared_error: 1.8108 - val_y2_output_root_mean_squared_error: 3.4846
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.5197 - y1_output_loss: 2.7486 - y2_output_loss: 5.7130 - y1_output_root_mean_squared_error: 1.6642 - y2_output_root_mean_squared_error: 2.3980 - val_loss: 10.2068 - val_y1_output_loss: 3.8582 - val_y2_output_loss: 6.5792 - val_y1_output_root_mean_squared_error: 1.9807 - val_y2_output_root_mean_squared_error: 2.5067
# Epoch 39/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.8269 - y1_output_loss: 3.2024 - y2_output_loss: 7.5872 - y1_output_root_mean_squared_error: 1.7982 - y2_output_root_mean_squared_error: 2.7556 - val_loss: 109.9437 - val_y1_output_loss: 32.6140 - val_y2_output_loss: 76.8860 - val_y1_output_root_mean_squared_error: 5.7648 - val_y2_output_root_mean_squared_error: 8.7585
# Epoch 40/500
# 614/614 [==============================] - 0s 137us/sample - loss: 10.9651 - y1_output_loss: 3.7790 - y2_output_loss: 7.1390 - y1_output_root_mean_squared_error: 1.9527 - y2_output_root_mean_squared_error: 2.6744 - val_loss: 6.9321 - val_y1_output_loss: 2.3578 - val_y2_output_loss: 4.5424 - val_y1_output_root_mean_squared_error: 1.5550 - val_y2_output_root_mean_squared_error: 2.1246
# Epoch 41/500
# 614/614 [==============================] - 0s 156us/sample - loss: 6.8542 - y1_output_loss: 2.3208 - y2_output_loss: 4.4989 - y1_output_root_mean_squared_error: 1.5269 - y2_output_root_mean_squared_error: 2.1267 - val_loss: 7.7597 - val_y1_output_loss: 2.8743 - val_y2_output_loss: 5.0496 - val_y1_output_root_mean_squared_error: 1.7119 - val_y2_output_root_mean_squared_error: 2.1975
# Epoch 42/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.3040 - y1_output_loss: 2.5063 - y2_output_loss: 4.8946 - y1_output_root_mean_squared_error: 1.5597 - y2_output_root_mean_squared_error: 2.2071 - val_loss: 29.8370 - val_y1_output_loss: 9.5597 - val_y2_output_loss: 21.1525 - val_y1_output_root_mean_squared_error: 3.0861 - val_y2_output_root_mean_squared_error: 4.5070
# Epoch 43/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.5208 - y1_output_loss: 2.9472 - y2_output_loss: 6.5932 - y1_output_root_mean_squared_error: 1.7090 - y2_output_root_mean_squared_error: 2.5691 - val_loss: 8.0103 - val_y1_output_loss: 3.3098 - val_y2_output_loss: 4.5995 - val_y1_output_root_mean_squared_error: 1.8503 - val_y2_output_root_mean_squared_error: 2.1416
# Epoch 44/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.4911 - y1_output_loss: 2.2206 - y2_output_loss: 4.2298 - y1_output_root_mean_squared_error: 1.4954 - y2_output_root_mean_squared_error: 2.0628 - val_loss: 7.3152 - val_y1_output_loss: 2.4050 - val_y2_output_loss: 5.1135 - val_y1_output_root_mean_squared_error: 1.5657 - val_y2_output_root_mean_squared_error: 2.2054
# Epoch 45/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.1818 - y1_output_loss: 1.9607 - y2_output_loss: 5.2642 - y1_output_root_mean_squared_error: 1.4048 - y2_output_root_mean_squared_error: 2.2822 - val_loss: 9.9676 - val_y1_output_loss: 2.4218 - val_y2_output_loss: 7.2233 - val_y1_output_root_mean_squared_error: 1.5821 - val_y2_output_root_mean_squared_error: 2.7322
# Epoch 46/500
# 614/614 [==============================] - 0s 151us/sample - loss: 6.7032 - y1_output_loss: 2.1653 - y2_output_loss: 4.6335 - y1_output_root_mean_squared_error: 1.4741 - y2_output_root_mean_squared_error: 2.1284 - val_loss: 15.6752 - val_y1_output_loss: 3.2602 - val_y2_output_loss: 11.8915 - val_y1_output_root_mean_squared_error: 1.8385 - val_y2_output_root_mean_squared_error: 3.5064
# Epoch 47/500
# 614/614 [==============================] - 0s 147us/sample - loss: 8.4113 - y1_output_loss: 2.6883 - y2_output_loss: 5.7244 - y1_output_root_mean_squared_error: 1.6387 - y2_output_root_mean_squared_error: 2.3929 - val_loss: 10.5302 - val_y1_output_loss: 3.1926 - val_y2_output_loss: 7.0137 - val_y1_output_root_mean_squared_error: 1.8085 - val_y2_output_root_mean_squared_error: 2.6944
# Epoch 48/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.6190 - y1_output_loss: 2.3783 - y2_output_loss: 5.1875 - y1_output_root_mean_squared_error: 1.5461 - y2_output_root_mean_squared_error: 2.2866 - val_loss: 7.0103 - val_y1_output_loss: 2.6515 - val_y2_output_loss: 4.5634 - val_y1_output_root_mean_squared_error: 1.6346 - val_y2_output_root_mean_squared_error: 2.0829
# Epoch 49/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.8851 - y1_output_loss: 2.2924 - y2_output_loss: 4.6290 - y1_output_root_mean_squared_error: 1.5133 - y2_output_root_mean_squared_error: 2.1436 - val_loss: 7.1546 - val_y1_output_loss: 2.7526 - val_y2_output_loss: 4.4914 - val_y1_output_root_mean_squared_error: 1.6805 - val_y2_output_root_mean_squared_error: 2.0810
# Epoch 50/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.3986 - y1_output_loss: 2.0873 - y2_output_loss: 4.3395 - y1_output_root_mean_squared_error: 1.4426 - y2_output_root_mean_squared_error: 2.0779 - val_loss: 13.1627 - val_y1_output_loss: 3.6353 - val_y2_output_loss: 9.0912 - val_y1_output_root_mean_squared_error: 1.9358 - val_y2_output_root_mean_squared_error: 3.0685
# Epoch 51/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.1647 - y1_output_loss: 2.5571 - y2_output_loss: 5.5637 - y1_output_root_mean_squared_error: 1.5964 - y2_output_root_mean_squared_error: 2.3699 - val_loss: 8.0326 - val_y1_output_loss: 3.0279 - val_y2_output_loss: 5.3009 - val_y1_output_root_mean_squared_error: 1.7458 - val_y2_output_root_mean_squared_error: 2.2326
# Epoch 52/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.5068 - y1_output_loss: 1.9010 - y2_output_loss: 4.6692 - y1_output_root_mean_squared_error: 1.3657 - y2_output_root_mean_squared_error: 2.1544 - val_loss: 22.6936 - val_y1_output_loss: 6.3028 - val_y2_output_loss: 15.6270 - val_y1_output_root_mean_squared_error: 2.5453 - val_y2_output_root_mean_squared_error: 4.0268
# Epoch 53/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.3145 - y1_output_loss: 1.8881 - y2_output_loss: 4.4837 - y1_output_root_mean_squared_error: 1.3780 - y2_output_root_mean_squared_error: 2.1013 - val_loss: 11.6426 - val_y1_output_loss: 2.3219 - val_y2_output_loss: 8.9321 - val_y1_output_root_mean_squared_error: 1.5526 - val_y2_output_root_mean_squared_error: 3.0384
# Epoch 54/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.1820 - y1_output_loss: 2.1902 - y2_output_loss: 4.9644 - y1_output_root_mean_squared_error: 1.4768 - y2_output_root_mean_squared_error: 2.2363 - val_loss: 7.7114 - val_y1_output_loss: 2.3514 - val_y2_output_loss: 5.6504 - val_y1_output_root_mean_squared_error: 1.5399 - val_y2_output_root_mean_squared_error: 2.3109
# Epoch 55/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.0075 - y1_output_loss: 1.8273 - y2_output_loss: 4.1464 - y1_output_root_mean_squared_error: 1.3551 - y2_output_root_mean_squared_error: 2.0423 - val_loss: 7.1011 - val_y1_output_loss: 2.3958 - val_y2_output_loss: 4.6806 - val_y1_output_root_mean_squared_error: 1.5724 - val_y2_output_root_mean_squared_error: 2.1514
# Epoch 56/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.2758 - y1_output_loss: 1.8498 - y2_output_loss: 4.3844 - y1_output_root_mean_squared_error: 1.3614 - y2_output_root_mean_squared_error: 2.1029 - val_loss: 9.2692 - val_y1_output_loss: 3.3801 - val_y2_output_loss: 6.2159 - val_y1_output_root_mean_squared_error: 1.8432 - val_y2_output_root_mean_squared_error: 2.4232
# Epoch 57/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.8583 - y1_output_loss: 1.7664 - y2_output_loss: 4.0914 - y1_output_root_mean_squared_error: 1.3337 - y2_output_root_mean_squared_error: 2.0198 - val_loss: 6.2207 - val_y1_output_loss: 1.7637 - val_y2_output_loss: 4.3300 - val_y1_output_root_mean_squared_error: 1.3508 - val_y2_output_root_mean_squared_error: 2.0967
# Epoch 58/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.8972 - y1_output_loss: 1.4626 - y2_output_loss: 3.4576 - y1_output_root_mean_squared_error: 1.2093 - y2_output_root_mean_squared_error: 1.8533 - val_loss: 5.2303 - val_y1_output_loss: 1.6408 - val_y2_output_loss: 3.6709 - val_y1_output_root_mean_squared_error: 1.3020 - val_y2_output_root_mean_squared_error: 1.8802
# Epoch 59/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.7966 - y1_output_loss: 1.4732 - y2_output_loss: 3.3394 - y1_output_root_mean_squared_error: 1.2124 - y2_output_root_mean_squared_error: 1.8240 - val_loss: 12.5577 - val_y1_output_loss: 3.3352 - val_y2_output_loss: 8.8214 - val_y1_output_root_mean_squared_error: 1.8529 - val_y2_output_root_mean_squared_error: 3.0207
# Epoch 60/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.9696 - y1_output_loss: 2.0075 - y2_output_loss: 4.9786 - y1_output_root_mean_squared_error: 1.4040 - y2_output_root_mean_squared_error: 2.2357 - val_loss: 5.8339 - val_y1_output_loss: 2.2283 - val_y2_output_loss: 3.5289 - val_y1_output_root_mean_squared_error: 1.5126 - val_y2_output_root_mean_squared_error: 1.8831
# Epoch 61/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.4455 - y1_output_loss: 1.2747 - y2_output_loss: 3.2328 - y1_output_root_mean_squared_error: 1.1297 - y2_output_root_mean_squared_error: 1.7802 - val_loss: 8.5929 - val_y1_output_loss: 1.8800 - val_y2_output_loss: 6.4535 - val_y1_output_root_mean_squared_error: 1.3937 - val_y2_output_root_mean_squared_error: 2.5788
# Epoch 62/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.7898 - y1_output_loss: 1.3900 - y2_output_loss: 3.3829 - y1_output_root_mean_squared_error: 1.1821 - y2_output_root_mean_squared_error: 1.8419 - val_loss: 5.7631 - val_y1_output_loss: 2.0771 - val_y2_output_loss: 3.6104 - val_y1_output_root_mean_squared_error: 1.4579 - val_y2_output_root_mean_squared_error: 1.9073
# Epoch 63/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.8520 - y1_output_loss: 1.3770 - y2_output_loss: 3.4585 - y1_output_root_mean_squared_error: 1.1778 - y2_output_root_mean_squared_error: 1.8614 - val_loss: 8.0269 - val_y1_output_loss: 2.0065 - val_y2_output_loss: 6.4059 - val_y1_output_root_mean_squared_error: 1.4213 - val_y2_output_root_mean_squared_error: 2.4509
# Epoch 64/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.1167 - y1_output_loss: 1.4639 - y2_output_loss: 3.6505 - y1_output_root_mean_squared_error: 1.2137 - y2_output_root_mean_squared_error: 1.9088 - val_loss: 9.7286 - val_y1_output_loss: 3.2256 - val_y2_output_loss: 6.6433 - val_y1_output_root_mean_squared_error: 1.8146 - val_y2_output_root_mean_squared_error: 2.5369
# Epoch 65/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.7761 - y1_output_loss: 1.2600 - y2_output_loss: 3.4753 - y1_output_root_mean_squared_error: 1.1266 - y2_output_root_mean_squared_error: 1.8727 - val_loss: 5.2806 - val_y1_output_loss: 1.8383 - val_y2_output_loss: 3.5507 - val_y1_output_root_mean_squared_error: 1.3689 - val_y2_output_root_mean_squared_error: 1.8457
# Epoch 66/500
# 614/614 [==============================] - 0s 178us/sample - loss: 4.7122 - y1_output_loss: 1.4162 - y2_output_loss: 3.2906 - y1_output_root_mean_squared_error: 1.1917 - y2_output_root_mean_squared_error: 1.8144 - val_loss: 4.4087 - val_y1_output_loss: 1.4916 - val_y2_output_loss: 3.0500 - val_y1_output_root_mean_squared_error: 1.2341 - val_y2_output_root_mean_squared_error: 1.6988
# Epoch 67/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.5003 - y1_output_loss: 1.5791 - y2_output_loss: 3.8868 - y1_output_root_mean_squared_error: 1.2615 - y2_output_root_mean_squared_error: 1.9771 - val_loss: 7.0442 - val_y1_output_loss: 2.4661 - val_y2_output_loss: 4.5394 - val_y1_output_root_mean_squared_error: 1.5963 - val_y2_output_root_mean_squared_error: 2.1204
# Epoch 68/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.6310 - y1_output_loss: 1.3215 - y2_output_loss: 3.2734 - y1_output_root_mean_squared_error: 1.1531 - y2_output_root_mean_squared_error: 1.8170 - val_loss: 4.4708 - val_y1_output_loss: 1.4093 - val_y2_output_loss: 3.1068 - val_y1_output_root_mean_squared_error: 1.1961 - val_y2_output_root_mean_squared_error: 1.7436
# Epoch 69/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1894 - y1_output_loss: 1.9138 - y2_output_loss: 4.3338 - y1_output_root_mean_squared_error: 1.3767 - y2_output_root_mean_squared_error: 2.0722 - val_loss: 4.5927 - val_y1_output_loss: 1.5430 - val_y2_output_loss: 3.0465 - val_y1_output_root_mean_squared_error: 1.2431 - val_y2_output_root_mean_squared_error: 1.7457
# Epoch 70/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.4861 - y1_output_loss: 1.2347 - y2_output_loss: 3.2429 - y1_output_root_mean_squared_error: 1.1132 - y2_output_root_mean_squared_error: 1.8019 - val_loss: 6.4230 - val_y1_output_loss: 2.2107 - val_y2_output_loss: 4.3568 - val_y1_output_root_mean_squared_error: 1.5004 - val_y2_output_root_mean_squared_error: 2.0425
# Epoch 71/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.3836 - y1_output_loss: 1.3136 - y2_output_loss: 3.0910 - y1_output_root_mean_squared_error: 1.1391 - y2_output_root_mean_squared_error: 1.7567 - val_loss: 6.8632 - val_y1_output_loss: 1.6453 - val_y2_output_loss: 5.4376 - val_y1_output_root_mean_squared_error: 1.3006 - val_y2_output_root_mean_squared_error: 2.2741
# Epoch 72/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.8108 - y1_output_loss: 1.6746 - y2_output_loss: 4.1421 - y1_output_root_mean_squared_error: 1.2963 - y2_output_root_mean_squared_error: 2.0323 - val_loss: 4.3650 - val_y1_output_loss: 1.4462 - val_y2_output_loss: 3.0241 - val_y1_output_root_mean_squared_error: 1.2164 - val_y2_output_root_mean_squared_error: 1.6986
# Epoch 73/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.3157 - y1_output_loss: 1.1178 - y2_output_loss: 3.1801 - y1_output_root_mean_squared_error: 1.0549 - y2_output_root_mean_squared_error: 1.7897 - val_loss: 3.6104 - val_y1_output_loss: 1.0868 - val_y2_output_loss: 2.5444 - val_y1_output_root_mean_squared_error: 1.0587 - val_y2_output_root_mean_squared_error: 1.5778
# Epoch 74/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.8524 - y1_output_loss: 1.0580 - y2_output_loss: 2.7603 - y1_output_root_mean_squared_error: 1.0325 - y2_output_root_mean_squared_error: 1.6692 - val_loss: 3.3892 - val_y1_output_loss: 1.0201 - val_y2_output_loss: 2.4635 - val_y1_output_root_mean_squared_error: 1.0146 - val_y2_output_root_mean_squared_error: 1.5362
# Epoch 75/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.7157 - y1_output_loss: 1.0764 - y2_output_loss: 2.6260 - y1_output_root_mean_squared_error: 1.0386 - y2_output_root_mean_squared_error: 1.6239 - val_loss: 7.6512 - val_y1_output_loss: 1.3547 - val_y2_output_loss: 6.0373 - val_y1_output_root_mean_squared_error: 1.1817 - val_y2_output_root_mean_squared_error: 2.5009
# Epoch 76/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.8218 - y1_output_loss: 1.0083 - y2_output_loss: 2.7810 - y1_output_root_mean_squared_error: 1.0076 - y2_output_root_mean_squared_error: 1.6753 - val_loss: 3.8545 - val_y1_output_loss: 1.1028 - val_y2_output_loss: 2.8840 - val_y1_output_root_mean_squared_error: 1.0631 - val_y2_output_root_mean_squared_error: 1.6506
# Epoch 77/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.1026 - y1_output_loss: 2.4218 - y2_output_loss: 5.6675 - y1_output_root_mean_squared_error: 1.5557 - y2_output_root_mean_squared_error: 2.3838 - val_loss: 9.1453 - val_y1_output_loss: 3.7201 - val_y2_output_loss: 5.2740 - val_y1_output_root_mean_squared_error: 1.9362 - val_y2_output_root_mean_squared_error: 2.3230
# Epoch 78/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.5962 - y1_output_loss: 1.8494 - y2_output_loss: 4.1712 - y1_output_root_mean_squared_error: 1.3047 - y2_output_root_mean_squared_error: 1.9733 - val_loss: 77.3979 - val_y1_output_loss: 20.5523 - val_y2_output_loss: 56.2476 - val_y1_output_root_mean_squared_error: 4.5937 - val_y2_output_root_mean_squared_error: 7.5031
# Epoch 79/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.7913 - y1_output_loss: 1.8353 - y2_output_loss: 3.9184 - y1_output_root_mean_squared_error: 1.3590 - y2_output_root_mean_squared_error: 1.9860 - val_loss: 3.4635 - val_y1_output_loss: 0.8048 - val_y2_output_loss: 2.6197 - val_y1_output_root_mean_squared_error: 0.9092 - val_y2_output_root_mean_squared_error: 1.6239
# Epoch 80/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.7451 - y1_output_loss: 0.9715 - y2_output_loss: 2.8001 - y1_output_root_mean_squared_error: 0.9861 - y2_output_root_mean_squared_error: 1.6651 - val_loss: 6.8306 - val_y1_output_loss: 1.6694 - val_y2_output_loss: 4.9851 - val_y1_output_root_mean_squared_error: 1.3086 - val_y2_output_root_mean_squared_error: 2.2623
# Epoch 81/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.9923 - y1_output_loss: 0.8208 - y2_output_loss: 2.1592 - y1_output_root_mean_squared_error: 0.9074 - y2_output_root_mean_squared_error: 1.4727 - val_loss: 3.5843 - val_y1_output_loss: 0.8131 - val_y2_output_loss: 2.9534 - val_y1_output_root_mean_squared_error: 0.9064 - val_y2_output_root_mean_squared_error: 1.6622
# Epoch 82/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.6087 - y1_output_loss: 0.8700 - y2_output_loss: 2.7691 - y1_output_root_mean_squared_error: 0.9331 - y2_output_root_mean_squared_error: 1.6547 - val_loss: 5.7249 - val_y1_output_loss: 1.0568 - val_y2_output_loss: 4.7793 - val_y1_output_root_mean_squared_error: 1.0422 - val_y2_output_root_mean_squared_error: 2.1538
# Epoch 83/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.7675 - y1_output_loss: 1.1695 - y2_output_loss: 3.5685 - y1_output_root_mean_squared_error: 1.0829 - y2_output_root_mean_squared_error: 1.8960 - val_loss: 3.4702 - val_y1_output_loss: 1.0992 - val_y2_output_loss: 2.4668 - val_y1_output_root_mean_squared_error: 1.0628 - val_y2_output_root_mean_squared_error: 1.5299
# Epoch 84/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.4736 - y1_output_loss: 0.9627 - y2_output_loss: 2.5080 - y1_output_root_mean_squared_error: 0.9813 - y2_output_root_mean_squared_error: 1.5845 - val_loss: 4.9344 - val_y1_output_loss: 0.6867 - val_y2_output_loss: 4.4419 - val_y1_output_root_mean_squared_error: 0.8391 - val_y2_output_root_mean_squared_error: 2.0567
# Epoch 85/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.5948 - y1_output_loss: 0.9791 - y2_output_loss: 2.6123 - y1_output_root_mean_squared_error: 0.9822 - y2_output_root_mean_squared_error: 1.6217 - val_loss: 4.5171 - val_y1_output_loss: 1.2576 - val_y2_output_loss: 3.4452 - val_y1_output_root_mean_squared_error: 1.1327 - val_y2_output_root_mean_squared_error: 1.7984
# Epoch 86/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.2795 - y1_output_loss: 0.8312 - y2_output_loss: 2.4208 - y1_output_root_mean_squared_error: 0.9144 - y2_output_root_mean_squared_error: 1.5631 - val_loss: 2.7182 - val_y1_output_loss: 0.6915 - val_y2_output_loss: 2.0445 - val_y1_output_root_mean_squared_error: 0.8474 - val_y2_output_root_mean_squared_error: 1.4143
# Epoch 87/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5797 - y1_output_loss: 0.8444 - y2_output_loss: 2.8736 - y1_output_root_mean_squared_error: 0.9197 - y2_output_root_mean_squared_error: 1.6534 - val_loss: 15.6891 - val_y1_output_loss: 1.6188 - val_y2_output_loss: 13.6624 - val_y1_output_root_mean_squared_error: 1.2827 - val_y2_output_root_mean_squared_error: 3.7475
# Epoch 88/500
# 614/614 [==============================] - 0s 147us/sample - loss: 14.4211 - y1_output_loss: 4.2954 - y2_output_loss: 9.9947 - y1_output_root_mean_squared_error: 2.0825 - y2_output_root_mean_squared_error: 3.1756 - val_loss: 3.1914 - val_y1_output_loss: 0.9621 - val_y2_output_loss: 2.2365 - val_y1_output_root_mean_squared_error: 0.9983 - val_y2_output_root_mean_squared_error: 1.4815
# Epoch 89/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3174 - y1_output_loss: 0.9227 - y2_output_loss: 2.3775 - y1_output_root_mean_squared_error: 0.9612 - y2_output_root_mean_squared_error: 1.5471 - val_loss: 3.0344 - val_y1_output_loss: 0.8196 - val_y2_output_loss: 2.2378 - val_y1_output_root_mean_squared_error: 0.9215 - val_y2_output_root_mean_squared_error: 1.4783
# Epoch 90/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5892 - y1_output_loss: 0.7351 - y2_output_loss: 1.8351 - y1_output_root_mean_squared_error: 0.8602 - y2_output_root_mean_squared_error: 1.3599 - val_loss: 3.1437 - val_y1_output_loss: 0.6951 - val_y2_output_loss: 2.5630 - val_y1_output_root_mean_squared_error: 0.8436 - val_y2_output_root_mean_squared_error: 1.5595
# Epoch 91/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.5427 - y1_output_loss: 1.2797 - y2_output_loss: 3.2292 - y1_output_root_mean_squared_error: 1.1332 - y2_output_root_mean_squared_error: 1.8051 - val_loss: 2.8876 - val_y1_output_loss: 0.7900 - val_y2_output_loss: 2.1020 - val_y1_output_root_mean_squared_error: 0.8943 - val_y2_output_root_mean_squared_error: 1.4449
# Epoch 92/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.2832 - y1_output_loss: 0.8625 - y2_output_loss: 2.4059 - y1_output_root_mean_squared_error: 0.9299 - y2_output_root_mean_squared_error: 1.5552 - val_loss: 4.8619 - val_y1_output_loss: 1.0904 - val_y2_output_loss: 3.8356 - val_y1_output_root_mean_squared_error: 1.0450 - val_y2_output_root_mean_squared_error: 1.9416
# Epoch 93/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.4646 - y1_output_loss: 0.8543 - y2_output_loss: 2.5825 - y1_output_root_mean_squared_error: 0.9271 - y2_output_root_mean_squared_error: 1.6140 - val_loss: 2.7259 - val_y1_output_loss: 0.6641 - val_y2_output_loss: 2.1038 - val_y1_output_root_mean_squared_error: 0.8195 - val_y2_output_root_mean_squared_error: 1.4333
# Epoch 94/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.7090 - y1_output_loss: 0.7258 - y2_output_loss: 2.0157 - y1_output_root_mean_squared_error: 0.8497 - y2_output_root_mean_squared_error: 1.4096 - val_loss: 2.7977 - val_y1_output_loss: 0.6257 - val_y2_output_loss: 2.2277 - val_y1_output_root_mean_squared_error: 0.8057 - val_y2_output_root_mean_squared_error: 1.4658
# Epoch 95/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5665 - y1_output_loss: 0.6418 - y2_output_loss: 2.0289 - y1_output_root_mean_squared_error: 0.7919 - y2_output_root_mean_squared_error: 1.3926 - val_loss: 16.7361 - val_y1_output_loss: 2.5421 - val_y2_output_loss: 13.7034 - val_y1_output_root_mean_squared_error: 1.6070 - val_y2_output_root_mean_squared_error: 3.7621
# Epoch 96/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.1560 - y1_output_loss: 1.1135 - y2_output_loss: 3.0184 - y1_output_root_mean_squared_error: 1.0595 - y2_output_root_mean_squared_error: 1.7417 - val_loss: 3.8499 - val_y1_output_loss: 0.9842 - val_y2_output_loss: 3.0016 - val_y1_output_root_mean_squared_error: 0.9961 - val_y2_output_root_mean_squared_error: 1.6905
# Epoch 97/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.2944 - y1_output_loss: 0.8118 - y2_output_loss: 2.4692 - y1_output_root_mean_squared_error: 0.8965 - y2_output_root_mean_squared_error: 1.5782 - val_loss: 3.1921 - val_y1_output_loss: 0.8871 - val_y2_output_loss: 2.3962 - val_y1_output_root_mean_squared_error: 0.9542 - val_y2_output_root_mean_squared_error: 1.5105
# Epoch 98/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.4625 - y1_output_loss: 0.5991 - y2_output_loss: 1.8552 - y1_output_root_mean_squared_error: 0.7757 - y2_output_root_mean_squared_error: 1.3641 - val_loss: 2.3510 - val_y1_output_loss: 0.4620 - val_y2_output_loss: 1.8861 - val_y1_output_root_mean_squared_error: 0.6909 - val_y2_output_root_mean_squared_error: 1.3688
# Epoch 99/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.3592 - y1_output_loss: 0.5967 - y2_output_loss: 1.7600 - y1_output_root_mean_squared_error: 0.7730 - y2_output_root_mean_squared_error: 1.3273 - val_loss: 4.2741 - val_y1_output_loss: 1.3917 - val_y2_output_loss: 2.8703 - val_y1_output_root_mean_squared_error: 1.2005 - val_y2_output_root_mean_squared_error: 1.6831
# Epoch 100/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.3152 - y1_output_loss: 0.5825 - y2_output_loss: 1.7258 - y1_output_root_mean_squared_error: 0.7631 - y2_output_root_mean_squared_error: 1.3164 - val_loss: 2.7263 - val_y1_output_loss: 0.5677 - val_y2_output_loss: 2.1222 - val_y1_output_root_mean_squared_error: 0.7606 - val_y2_output_root_mean_squared_error: 1.4655
# Epoch 101/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.2267 - y1_output_loss: 0.5276 - y2_output_loss: 1.7385 - y1_output_root_mean_squared_error: 0.7244 - y2_output_root_mean_squared_error: 1.3046 - val_loss: 5.8888 - val_y1_output_loss: 1.0274 - val_y2_output_loss: 4.6968 - val_y1_output_root_mean_squared_error: 1.0178 - val_y2_output_root_mean_squared_error: 2.2029
# Epoch 102/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.8532 - y1_output_loss: 0.7626 - y2_output_loss: 2.0790 - y1_output_root_mean_squared_error: 0.8737 - y2_output_root_mean_squared_error: 1.4456 - val_loss: 3.9831 - val_y1_output_loss: 1.0347 - val_y2_output_loss: 2.8554 - val_y1_output_root_mean_squared_error: 1.0197 - val_y2_output_root_mean_squared_error: 1.7156
# Epoch 103/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6411 - y1_output_loss: 0.6845 - y2_output_loss: 1.9517 - y1_output_root_mean_squared_error: 0.8280 - y2_output_root_mean_squared_error: 1.3984 - val_loss: 3.5667 - val_y1_output_loss: 0.5581 - val_y2_output_loss: 3.1214 - val_y1_output_root_mean_squared_error: 0.7540 - val_y2_output_root_mean_squared_error: 1.7315
# Epoch 104/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.3790 - y1_output_loss: 0.5216 - y2_output_loss: 1.8555 - y1_output_root_mean_squared_error: 0.7242 - y2_output_root_mean_squared_error: 1.3618 - val_loss: 3.4233 - val_y1_output_loss: 0.7757 - val_y2_output_loss: 2.5717 - val_y1_output_root_mean_squared_error: 0.8883 - val_y2_output_root_mean_squared_error: 1.6230
# Epoch 105/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.7095 - y1_output_loss: 0.5845 - y2_output_loss: 2.1026 - y1_output_root_mean_squared_error: 0.7677 - y2_output_root_mean_squared_error: 1.4561 - val_loss: 3.1673 - val_y1_output_loss: 0.6971 - val_y2_output_loss: 2.4074 - val_y1_output_root_mean_squared_error: 0.8469 - val_y2_output_root_mean_squared_error: 1.5653
# Epoch 106/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9972 - y1_output_loss: 0.7436 - y2_output_loss: 2.2642 - y1_output_root_mean_squared_error: 0.8573 - y2_output_root_mean_squared_error: 1.5040 - val_loss: 8.2607 - val_y1_output_loss: 3.1408 - val_y2_output_loss: 4.9618 - val_y1_output_root_mean_squared_error: 1.8046 - val_y2_output_root_mean_squared_error: 2.2370
# Epoch 107/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5453 - y1_output_loss: 0.9786 - y2_output_loss: 2.5517 - y1_output_root_mean_squared_error: 0.9911 - y2_output_root_mean_squared_error: 1.6009 - val_loss: 3.6451 - val_y1_output_loss: 0.6405 - val_y2_output_loss: 3.0872 - val_y1_output_root_mean_squared_error: 0.8052 - val_y2_output_root_mean_squared_error: 1.7311
# Epoch 108/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5594 - y1_output_loss: 0.6549 - y2_output_loss: 1.8962 - y1_output_root_mean_squared_error: 0.8110 - y2_output_root_mean_squared_error: 1.3790 - val_loss: 4.6968 - val_y1_output_loss: 0.9631 - val_y2_output_loss: 3.8919 - val_y1_output_root_mean_squared_error: 0.9844 - val_y2_output_root_mean_squared_error: 1.9307
# Epoch 109/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.1934 - y1_output_loss: 0.7560 - y2_output_loss: 2.4405 - y1_output_root_mean_squared_error: 0.8697 - y2_output_root_mean_squared_error: 1.5611 - val_loss: 3.1094 - val_y1_output_loss: 1.0255 - val_y2_output_loss: 2.0725 - val_y1_output_root_mean_squared_error: 1.0268 - val_y2_output_root_mean_squared_error: 1.4336
# Epoch 110/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.4882 - y1_output_loss: 0.5718 - y2_output_loss: 1.9239 - y1_output_root_mean_squared_error: 0.7577 - y2_output_root_mean_squared_error: 1.3835 - val_loss: 6.2024 - val_y1_output_loss: 1.9925 - val_y2_output_loss: 4.1578 - val_y1_output_root_mean_squared_error: 1.4319 - val_y2_output_root_mean_squared_error: 2.0376
# Epoch 111/500
# 614/614 [==============================] - 0s 158us/sample - loss: 4.3488 - y1_output_loss: 1.4870 - y2_output_loss: 3.1614 - y1_output_root_mean_squared_error: 1.1335 - y2_output_root_mean_squared_error: 1.7504 - val_loss: 27.8725 - val_y1_output_loss: 8.0730 - val_y2_output_loss: 20.1993 - val_y1_output_root_mean_squared_error: 2.8551 - val_y2_output_root_mean_squared_error: 4.4408
# Epoch 112/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7872 - y1_output_loss: 0.7783 - y2_output_loss: 1.9932 - y1_output_root_mean_squared_error: 0.8859 - y2_output_root_mean_squared_error: 1.4150 - val_loss: 3.1350 - val_y1_output_loss: 0.9621 - val_y2_output_loss: 2.2124 - val_y1_output_root_mean_squared_error: 0.9940 - val_y2_output_root_mean_squared_error: 1.4653
# Epoch 113/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.9378 - y1_output_loss: 0.9535 - y2_output_loss: 3.0015 - y1_output_root_mean_squared_error: 0.9751 - y2_output_root_mean_squared_error: 1.7283 - val_loss: 5.5451 - val_y1_output_loss: 1.1918 - val_y2_output_loss: 4.5278 - val_y1_output_root_mean_squared_error: 1.1072 - val_y2_output_root_mean_squared_error: 2.0783
# Epoch 114/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.1114 - y1_output_loss: 0.6317 - y2_output_loss: 2.4548 - y1_output_root_mean_squared_error: 0.7971 - y2_output_root_mean_squared_error: 1.5735 - val_loss: 2.3292 - val_y1_output_loss: 0.6758 - val_y2_output_loss: 1.6377 - val_y1_output_root_mean_squared_error: 0.8319 - val_y2_output_root_mean_squared_error: 1.2795
# Epoch 115/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.1633 - y1_output_loss: 0.5076 - y2_output_loss: 1.6753 - y1_output_root_mean_squared_error: 0.7085 - y2_output_root_mean_squared_error: 1.2889 - val_loss: 3.4113 - val_y1_output_loss: 0.3945 - val_y2_output_loss: 3.1283 - val_y1_output_root_mean_squared_error: 0.6352 - val_y2_output_root_mean_squared_error: 1.7343
# Epoch 116/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5895 - y1_output_loss: 0.5718 - y2_output_loss: 1.9991 - y1_output_root_mean_squared_error: 0.7592 - y2_output_root_mean_squared_error: 1.4188 - val_loss: 2.0586 - val_y1_output_loss: 0.3981 - val_y2_output_loss: 1.6455 - val_y1_output_root_mean_squared_error: 0.6328 - val_y2_output_root_mean_squared_error: 1.2877
# Epoch 117/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.3435 - y1_output_loss: 0.5102 - y2_output_loss: 1.8125 - y1_output_root_mean_squared_error: 0.7171 - y2_output_root_mean_squared_error: 1.3525 - val_loss: 2.0313 - val_y1_output_loss: 0.4327 - val_y2_output_loss: 1.5776 - val_y1_output_root_mean_squared_error: 0.6604 - val_y2_output_root_mean_squared_error: 1.2630
# Epoch 118/500
# 614/614 [==============================] - 0s 152us/sample - loss: 2.1014 - y1_output_loss: 0.4774 - y2_output_loss: 1.6900 - y1_output_root_mean_squared_error: 0.6812 - y2_output_root_mean_squared_error: 1.2796 - val_loss: 16.5670 - val_y1_output_loss: 5.1936 - val_y2_output_loss: 11.3492 - val_y1_output_root_mean_squared_error: 2.3096 - val_y2_output_root_mean_squared_error: 3.3515
# Epoch 119/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.0222 - y1_output_loss: 0.7775 - y2_output_loss: 2.2186 - y1_output_root_mean_squared_error: 0.8857 - y2_output_root_mean_squared_error: 1.4959 - val_loss: 2.1758 - val_y1_output_loss: 0.5247 - val_y2_output_loss: 1.6705 - val_y1_output_root_mean_squared_error: 0.7301 - val_y2_output_root_mean_squared_error: 1.2817
# Epoch 120/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.1063 - y1_output_loss: 0.5657 - y2_output_loss: 1.5372 - y1_output_root_mean_squared_error: 0.7485 - y2_output_root_mean_squared_error: 1.2434 - val_loss: 2.6317 - val_y1_output_loss: 0.6701 - val_y2_output_loss: 1.9156 - val_y1_output_root_mean_squared_error: 0.8160 - val_y2_output_root_mean_squared_error: 1.4021
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4153 - y1_output_loss: 0.1297 - y2_output_loss: 0.2823 - y1_output_root_mean_squared_error: 0.3613 - y2_output_root_mean_squared_error: 0.5337 - val_loss: 0.6416 - val_y1_output_loss: 0.1586 - val_y2_output_loss: 0.4857 - val_y1_output_root_mean_squared_error: 0.4003 - val_y2_output_root_mean_squared_error: 0.6938
# Epoch 462/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3824 - y1_output_loss: 0.1305 - y2_output_loss: 0.2513 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5023 - val_loss: 0.9682 - val_y1_output_loss: 0.1999 - val_y2_output_loss: 0.7472 - val_y1_output_root_mean_squared_error: 0.4487 - val_y2_output_root_mean_squared_error: 0.8757
# Epoch 463/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4567 - y1_output_loss: 0.1369 - y2_output_loss: 0.3171 - y1_output_root_mean_squared_error: 0.3708 - y2_output_root_mean_squared_error: 0.5650 - val_loss: 0.7609 - val_y1_output_loss: 0.1631 - val_y2_output_loss: 0.5838 - val_y1_output_root_mean_squared_error: 0.4044 - val_y2_output_root_mean_squared_error: 0.7729
# Epoch 464/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4159 - y1_output_loss: 0.1243 - y2_output_loss: 0.2883 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.5392 - val_loss: 0.5836 - val_y1_output_loss: 0.1217 - val_y2_output_loss: 0.4673 - val_y1_output_root_mean_squared_error: 0.3496 - val_y2_output_root_mean_squared_error: 0.6793
# Epoch 465/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.4740 - y1_output_loss: 0.1496 - y2_output_loss: 0.3248 - y1_output_root_mean_squared_error: 0.3884 - y2_output_root_mean_squared_error: 0.5684 - val_loss: 0.7612 - val_y1_output_loss: 0.1663 - val_y2_output_loss: 0.6086 - val_y1_output_root_mean_squared_error: 0.4118 - val_y2_output_root_mean_squared_error: 0.7692
# Epoch 466/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4349 - y1_output_loss: 0.1398 - y2_output_loss: 0.2961 - y1_output_root_mean_squared_error: 0.3752 - y2_output_root_mean_squared_error: 0.5423 - val_loss: 1.1874 - val_y1_output_loss: 0.2252 - val_y2_output_loss: 0.9483 - val_y1_output_root_mean_squared_error: 0.4721 - val_y2_output_root_mean_squared_error: 0.9821
# Epoch 467/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.4501 - y1_output_loss: 0.1311 - y2_output_loss: 0.3165 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.5641 - val_loss: 0.7004 - val_y1_output_loss: 0.1902 - val_y2_output_loss: 0.5022 - val_y1_output_root_mean_squared_error: 0.4372 - val_y2_output_root_mean_squared_error: 0.7136
# Epoch 468/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4045 - y1_output_loss: 0.1293 - y2_output_loss: 0.2728 - y1_output_root_mean_squared_error: 0.3607 - y2_output_root_mean_squared_error: 0.5239 - val_loss: 0.5928 - val_y1_output_loss: 0.1243 - val_y2_output_loss: 0.4648 - val_y1_output_root_mean_squared_error: 0.3514 - val_y2_output_root_mean_squared_error: 0.6851
# Epoch 469/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3991 - y1_output_loss: 0.1372 - y2_output_loss: 0.2621 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5118 - val_loss: 0.6383 - val_y1_output_loss: 0.1748 - val_y2_output_loss: 0.4583 - val_y1_output_root_mean_squared_error: 0.4232 - val_y2_output_root_mean_squared_error: 0.6776
# Epoch 470/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4122 - y1_output_loss: 0.1272 - y2_output_loss: 0.2823 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5330 - val_loss: 0.6678 - val_y1_output_loss: 0.1616 - val_y2_output_loss: 0.4992 - val_y1_output_root_mean_squared_error: 0.4015 - val_y2_output_root_mean_squared_error: 0.7118
# Epoch 471/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3356 - y1_output_loss: 0.1201 - y2_output_loss: 0.2144 - y1_output_root_mean_squared_error: 0.3466 - y2_output_root_mean_squared_error: 0.4642 - val_loss: 0.8466 - val_y1_output_loss: 0.1810 - val_y2_output_loss: 0.6793 - val_y1_output_root_mean_squared_error: 0.4302 - val_y2_output_root_mean_squared_error: 0.8134
# Epoch 472/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.5002 - y1_output_loss: 0.1451 - y2_output_loss: 0.3550 - y1_output_root_mean_squared_error: 0.3808 - y2_output_root_mean_squared_error: 0.5960 - val_loss: 0.8844 - val_y1_output_loss: 0.1327 - val_y2_output_loss: 0.7749 - val_y1_output_root_mean_squared_error: 0.3644 - val_y2_output_root_mean_squared_error: 0.8670
# Epoch 473/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3730 - y1_output_loss: 0.1186 - y2_output_loss: 0.2560 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.5047 - val_loss: 0.9603 - val_y1_output_loss: 0.2675 - val_y2_output_loss: 0.6910 - val_y1_output_root_mean_squared_error: 0.5241 - val_y2_output_root_mean_squared_error: 0.8280
# Epoch 474/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.5198 - y1_output_loss: 0.1541 - y2_output_loss: 0.3643 - y1_output_root_mean_squared_error: 0.3923 - y2_output_root_mean_squared_error: 0.6049 - val_loss: 1.0292 - val_y1_output_loss: 0.2233 - val_y2_output_loss: 0.8080 - val_y1_output_root_mean_squared_error: 0.4764 - val_y2_output_root_mean_squared_error: 0.8957
# Epoch 475/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3699 - y1_output_loss: 0.1119 - y2_output_loss: 0.2650 - y1_output_root_mean_squared_error: 0.3351 - y2_output_root_mean_squared_error: 0.5075 - val_loss: 1.1597 - val_y1_output_loss: 0.1676 - val_y2_output_loss: 0.9548 - val_y1_output_root_mean_squared_error: 0.4115 - val_y2_output_root_mean_squared_error: 0.9952
# Epoch 476/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5420 - y1_output_loss: 0.1471 - y2_output_loss: 0.3939 - y1_output_root_mean_squared_error: 0.3842 - y2_output_root_mean_squared_error: 0.6280 - val_loss: 0.9143 - val_y1_output_loss: 0.2149 - val_y2_output_loss: 0.6824 - val_y1_output_root_mean_squared_error: 0.4636 - val_y2_output_root_mean_squared_error: 0.8363
# Epoch 477/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3846 - y1_output_loss: 0.1296 - y2_output_loss: 0.2568 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5041 - val_loss: 1.1330 - val_y1_output_loss: 0.1665 - val_y2_output_loss: 0.9380 - val_y1_output_root_mean_squared_error: 0.4086 - val_y2_output_root_mean_squared_error: 0.9829
# Epoch 478/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4482 - y1_output_loss: 0.1377 - y2_output_loss: 0.3086 - y1_output_root_mean_squared_error: 0.3728 - y2_output_root_mean_squared_error: 0.5561 - val_loss: 0.7888 - val_y1_output_loss: 0.1161 - val_y2_output_loss: 0.6846 - val_y1_output_root_mean_squared_error: 0.3436 - val_y2_output_root_mean_squared_error: 0.8189
# Epoch 479/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4144 - y1_output_loss: 0.1362 - y2_output_loss: 0.2783 - y1_output_root_mean_squared_error: 0.3674 - y2_output_root_mean_squared_error: 0.5286 - val_loss: 0.6528 - val_y1_output_loss: 0.1906 - val_y2_output_loss: 0.4659 - val_y1_output_root_mean_squared_error: 0.4333 - val_y2_output_root_mean_squared_error: 0.6820
# Epoch 480/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4160 - y1_output_loss: 0.1338 - y2_output_loss: 0.2829 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.5319 - val_loss: 1.0503 - val_y1_output_loss: 0.2739 - val_y2_output_loss: 0.7555 - val_y1_output_root_mean_squared_error: 0.5263 - val_y2_output_root_mean_squared_error: 0.8794
# Epoch 481/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5680 - y1_output_loss: 0.1572 - y2_output_loss: 0.4068 - y1_output_root_mean_squared_error: 0.3975 - y2_output_root_mean_squared_error: 0.6403 - val_loss: 0.8508 - val_y1_output_loss: 0.1840 - val_y2_output_loss: 0.6444 - val_y1_output_root_mean_squared_error: 0.4301 - val_y2_output_root_mean_squared_error: 0.8160
# Epoch 482/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3545 - y1_output_loss: 0.1269 - y2_output_loss: 0.2264 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.4780 - val_loss: 0.8174 - val_y1_output_loss: 0.2173 - val_y2_output_loss: 0.6087 - val_y1_output_root_mean_squared_error: 0.4701 - val_y2_output_root_mean_squared_error: 0.7723
# Epoch 483/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.5093 - y1_output_loss: 0.1670 - y2_output_loss: 0.3403 - y1_output_root_mean_squared_error: 0.4093 - y2_output_root_mean_squared_error: 0.5846 - val_loss: 1.0347 - val_y1_output_loss: 0.1755 - val_y2_output_loss: 0.8751 - val_y1_output_root_mean_squared_error: 0.4213 - val_y2_output_root_mean_squared_error: 0.9258
# Epoch 484/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3562 - y1_output_loss: 0.1166 - y2_output_loss: 0.2393 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.4891 - val_loss: 0.6137 - val_y1_output_loss: 0.1318 - val_y2_output_loss: 0.4731 - val_y1_output_root_mean_squared_error: 0.3640 - val_y2_output_root_mean_squared_error: 0.6937
# Epoch 485/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4150 - y1_output_loss: 0.1221 - y2_output_loss: 0.2922 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.5414 - val_loss: 0.7201 - val_y1_output_loss: 0.1231 - val_y2_output_loss: 0.5831 - val_y1_output_root_mean_squared_error: 0.3544 - val_y2_output_root_mean_squared_error: 0.7710
# Epoch 486/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3811 - y1_output_loss: 0.1268 - y2_output_loss: 0.2578 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.5068 - val_loss: 1.0132 - val_y1_output_loss: 0.2419 - val_y2_output_loss: 0.7750 - val_y1_output_root_mean_squared_error: 0.4962 - val_y2_output_root_mean_squared_error: 0.8758
# Epoch 487/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3951 - y1_output_loss: 0.1137 - y2_output_loss: 0.2788 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.5299 - val_loss: 0.6114 - val_y1_output_loss: 0.1272 - val_y2_output_loss: 0.4829 - val_y1_output_root_mean_squared_error: 0.3616 - val_y2_output_root_mean_squared_error: 0.6933
# Epoch 488/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4165 - y1_output_loss: 0.1258 - y2_output_loss: 0.2890 - y1_output_root_mean_squared_error: 0.3555 - y2_output_root_mean_squared_error: 0.5386 - val_loss: 0.6734 - val_y1_output_loss: 0.1370 - val_y2_output_loss: 0.5303 - val_y1_output_root_mean_squared_error: 0.3731 - val_y2_output_root_mean_squared_error: 0.7309
# Epoch 489/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3851 - y1_output_loss: 0.1208 - y2_output_loss: 0.2652 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.5135 - val_loss: 0.9472 - val_y1_output_loss: 0.2196 - val_y2_output_loss: 0.7341 - val_y1_output_root_mean_squared_error: 0.4699 - val_y2_output_root_mean_squared_error: 0.8523
# Epoch 490/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3639 - y1_output_loss: 0.1231 - y2_output_loss: 0.2396 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.4901 - val_loss: 0.6842 - val_y1_output_loss: 0.1314 - val_y2_output_loss: 0.5456 - val_y1_output_root_mean_squared_error: 0.3634 - val_y2_output_root_mean_squared_error: 0.7431
# Epoch 491/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.6227 - y1_output_loss: 0.1602 - y2_output_loss: 0.4717 - y1_output_root_mean_squared_error: 0.4017 - y2_output_root_mean_squared_error: 0.6792 - val_loss: 2.8157 - val_y1_output_loss: 0.5383 - val_y2_output_loss: 2.1963 - val_y1_output_root_mean_squared_error: 0.7402 - val_y2_output_root_mean_squared_error: 1.5059
# Epoch 492/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.9121 - y1_output_loss: 0.2395 - y2_output_loss: 0.6653 - y1_output_root_mean_squared_error: 0.4915 - y2_output_root_mean_squared_error: 0.8189 - val_loss: 0.7284 - val_y1_output_loss: 0.1380 - val_y2_output_loss: 0.5819 - val_y1_output_root_mean_squared_error: 0.3726 - val_y2_output_root_mean_squared_error: 0.7678
# Epoch 493/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4629 - y1_output_loss: 0.1399 - y2_output_loss: 0.3235 - y1_output_root_mean_squared_error: 0.3736 - y2_output_root_mean_squared_error: 0.5686 - val_loss: 1.0468 - val_y1_output_loss: 0.2034 - val_y2_output_loss: 0.8607 - val_y1_output_root_mean_squared_error: 0.4561 - val_y2_output_root_mean_squared_error: 0.9158
# Epoch 494/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4443 - y1_output_loss: 0.1356 - y2_output_loss: 0.3072 - y1_output_root_mean_squared_error: 0.3685 - y2_output_root_mean_squared_error: 0.5555 - val_loss: 0.6668 - val_y1_output_loss: 0.1448 - val_y2_output_loss: 0.5275 - val_y1_output_root_mean_squared_error: 0.3764 - val_y2_output_root_mean_squared_error: 0.7247
# Epoch 495/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3224 - y1_output_loss: 0.1125 - y2_output_loss: 0.2079 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4579 - val_loss: 0.6045 - val_y1_output_loss: 0.1379 - val_y2_output_loss: 0.4583 - val_y1_output_root_mean_squared_error: 0.3731 - val_y2_output_root_mean_squared_error: 0.6821
# Epoch 496/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3760 - y1_output_loss: 0.1199 - y2_output_loss: 0.2537 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.5056 - val_loss: 0.6248 - val_y1_output_loss: 0.1727 - val_y2_output_loss: 0.4446 - val_y1_output_root_mean_squared_error: 0.4182 - val_y2_output_root_mean_squared_error: 0.6708
# Epoch 497/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4186 - y1_output_loss: 0.1413 - y2_output_loss: 0.2755 - y1_output_root_mean_squared_error: 0.3773 - y2_output_root_mean_squared_error: 0.5255 - val_loss: 0.6907 - val_y1_output_loss: 0.1373 - val_y2_output_loss: 0.5482 - val_y1_output_root_mean_squared_error: 0.3717 - val_y2_output_root_mean_squared_error: 0.7433
# Epoch 498/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3390 - y1_output_loss: 0.1148 - y2_output_loss: 0.2295 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.4761 - val_loss: 1.1752 - val_y1_output_loss: 0.3001 - val_y2_output_loss: 0.8588 - val_y1_output_root_mean_squared_error: 0.5447 - val_y2_output_root_mean_squared_error: 0.9373
# Epoch 499/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4238 - y1_output_loss: 0.1332 - y2_output_loss: 0.2875 - y1_output_root_mean_squared_error: 0.3657 - y2_output_root_mean_squared_error: 0.5386 - val_loss: 0.6355 - val_y1_output_loss: 0.1244 - val_y2_output_loss: 0.5053 - val_y1_output_root_mean_squared_error: 0.3574 - val_y2_output_root_mean_squared_error: 0.7126
# Epoch 500/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.9493 - y1_output_loss: 0.2384 - y2_output_loss: 0.7022 - y1_output_root_mean_squared_error: 0.4906 - y2_output_root_mean_squared_error: 0.8418 - val_loss: 0.6210 - val_y1_output_loss: 0.1359 - val_y2_output_loss: 0.4788 - val_y1_output_root_mean_squared_error: 0.3696 - val_y2_output_root_mean_squared_error: 0.6960

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.6210 - y1_output_loss: 0.1366 - y2_output_loss: 0.4892 - y1_output_root_mean_squared_error: 0.3696 - y2_output_root_mean_squared_error: 0.6960
# Loss = 0.6210184135994354, Y1_loss = 0.13656024634838104, Y1_mse = 0.3695952594280243, Y2_loss = 0.4892122149467468, Y2_mse = 0.6960012912750244

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
